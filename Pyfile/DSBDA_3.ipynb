# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('Datasets/income.csv')
df1.head()
df1.age_group.unique()
# Out:
# array(['18-30', '51-70', '31-50'], dtype=object)

# %%
print(df1)
# Out:
#    age_group  income
# 0      18-30     717
# 1      51-70     256
# 2      31-50     391
# 3      18-30     136
# 4      31-50     742
# 5      51-70     575
# 6      18-30     302
# 7      31-50     149
# 8      18-30     690
# 9      51-70     370
# 10     31-50     561
# 11     18-30     545
# 12     18-30     592
# 13     51-70     187
# 14     31-50     270
# 15     18-30     453
# 16     31-50     334
# 17     31-50     611
# 18     31-50     615
# 19     31-50     385
# 20     31-50     716
# 21     51-70     167
# 22     31-50     217
# 23     18-30      69
# 24     18-30     524
# 25     18-30     168
# 26     18-30      27
# 27     18-30     116
# 28     31-50     564
# 29     18-30     444
# 30     31-50     740
# 31     31-50     171
# 32     18-30     124
# 33     31-50      19
# 34     18-30     531
# 35     51-70     382
# 36     18-30     517
# 37     18-30     208
# 38     31-50     179
# 39     51-70     337
# 40     31-50     661
# 41     51-70     694
# 42     51-70     308
# 43     31-50      69
# 44     31-50     202
# 45     31-50     561
# 46     18-30     306
# 47     31-50     291
# 48     18-30     373
# 49     18-30     429
# 50     18-30      40
# 51     51-70     186
# 52     18-30     491
# 53     51-70     486
# 54     31-50     332
# 55     18-30     274
# 56     18-30     158
# 57     31-50     350
# 58     51-70      38
# 59     31-50     119

# %%
df1.groupby(df1.age_group).count()
# Out:
#            income
# age_group
# 18-30          24
# 31-50          24
# 51-70          12

# %%
df1.groupby(df1.age_group).min()
# Out:
#            income
# age_group
# 18-30          27
# 31-50          19
# 51-70          38

# %%
df1.groupby(df1.age_group).max()
# Out:
#            income
# age_group
# 18-30         717
# 31-50         742
# 51-70         694

# %%
df1.groupby(df1.age_group).mean()
# Out:
#                income
# age_group
# 18-30      343.083333
# 31-50      385.375000
# 51-70      332.166667

# %%
df1.groupby(df1.age_group).std()
# Out:
#                income
# age_group
# 18-30      209.962505
# 31-50      226.131707
# 51-70      185.896273

# %%
df1.groupby(df1.age_group).describe()
# Out:
#           income
#            count        mean         std   min     25%    50%     75%    max
# age_group
# 18-30       24.0  343.083333  209.962505  27.0  152.50  339.5  518.75  717.0
# 31-50       24.0  385.375000  226.131707  19.0  196.25  342.0  575.75  742.0
# 51-70       12.0  332.166667  185.896273  38.0  186.75  322.5  408.00  694.0

# %%
from sklearn import datasets
import pandas as pd
data = datasets.load_iris()
df = pd.DataFrame(data.data,columns=data.feature_names)
df['species'] = pd.Series(data.target)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df.species.unique()
# Out:
# array([0, 1, 2])

# %%
df.groupby(df.species)

# %%
df.groupby(df.species).count()
# Out:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# 0                       50                50                 50
# 1                       50                50                 50
# 2                       50                50                 50
#
#          petal width (cm)
# species
# 0                      50
# 1                      50
# 2                      50

# %%
df.groupby(df.species).max()
# Out:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# 0                      5.8               4.4                1.9
# 1                      7.0               3.4                5.1
# 2                      7.9               3.8                6.9
#
#          petal width (cm)
# species
# 0                     0.6
# 1                     1.8
# 2                     2.5

# %%
df.groupby(df.species).min()
# Out:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# 0                      4.3               2.3                1.0
# 1                      4.9               2.0                3.0
# 2                      4.9               2.2                4.5
#
#          petal width (cm)
# species
# 0                     0.1
# 1                     1.0
# 2                     1.4

# %%
df.groupby(df.species).mean()
# Out:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# 0                    5.006             3.428              1.462
# 1                    5.936             2.770              4.260
# 2                    6.588             2.974              5.552
#
#          petal width (cm)
# species
# 0                   0.246
# 1                   1.326
# 2                   2.026

# %%
df.groupby(df.species).std()
# Out:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# 0                 0.352490          0.379064           0.173664
# 1                 0.516171          0.313798           0.469911
# 2                 0.635880          0.322497           0.551895
#
#          petal width (cm)
# species
# 0                0.105386
# 1                0.197753
# 2                0.274650

# %%
df.groupby(df.species)["sepal length (cm)"].describe()
# Out:
#          count   mean       std  min    25%  50%  75%  max
# species
# 0         50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# 1         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# 2         50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9

# %%
df.groupby(df.species)["sepal width (cm)"].describe()
# Out:
#          count   mean       std  min    25%  50%    75%  max
# species
# 0         50.0  3.428  0.379064  2.3  3.200  3.4  3.675  4.4
# 1         50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# 2         50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8
